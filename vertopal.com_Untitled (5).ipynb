# %% [markdown]
# In \[1\]:
#
#     import numpy as np
#     import pandas as pd
#
# In \[2\]:
#
#     법정동=pd.read_csv("행정안전부_지역별(법정동) 성별 연령별 주민등록 인구수_20230430.csv",encoding="cp949")
#     법정동
#
# Out\[2\]:
#
# |     | 법정동코드 | 기준연월   | 시도명     | 시군구명 | 읍면동명 | 리명   | 계    |
# |-----|------------|------------|------------|----------|----------|--------|-------|
# | 0   | 1111010100 | 2023-04-30 | 서울특별시 | 종로구   | 청운동   | 청운동 | 2339  |
# | 1   | 1111010200 | 2023-04-30 | 서울특별시 | 종로구   | 신교동   | 신교동 | 1361  |
# | 2   | 1111010300 | 2023-04-30 | 서울특별시 | 종로구   | 궁정동   | 궁정동 | 192   |
# | 3   | 1111010400 | 2023-04-30 | 서울특별시 | 종로구   | 효자동   | 효자동 | 572   |
# | 4   | 1111010500 | 2023-04-30 | 서울특별시 | 종로구   | 창성동   | 창성동 | 414   |
# | ... | ...        | ...        | ...        | ...      | ...      | ...    | ...   |
# | 450 | 1174010600 | 2023-04-30 | 서울특별시 | 강동구   | 둔촌동   | 둔촌동 | 24160 |
# | 451 | 1174010700 | 2023-04-30 | 서울특별시 | 강동구   | 암사동   | 암사동 | 66418 |
# | 452 | 1174010800 | 2023-04-30 | 서울특별시 | 강동구   | 성내동   | 성내동 | 65051 |
# | 453 | 1174010900 | 2023-04-30 | 서울특별시 | 강동구   | 천호동   | 천호동 | 85764 |
# | 454 | 1174011000 | 2023-04-30 | 서울특별시 | 강동구   | 강일동   | 강일동 | 32855 |
#
# 455 rows × 7 columns
#
# In \[3\]:
#
#     비교결과 = 법정동['읍면동명'] == 법정동['리명']
#     동일한_개수 = sum(비교결과)
#
#     print(동일한_개수)
#
#     455
#
# In \[4\]:
#
#     법정동['법정동']=법정동['시도명']+' '+법정동['시군구명']+' '+법정동['읍면동명']
#     법정동
#
# Out\[4\]:
#
# |     | 법정동코드 | 기준연월   | 시도명     | 시군구명 | 읍면동명 | 리명   | 계    | 법정동                   |
# |-----|------------|------------|------------|----------|----------|--------|-------|--------------------------|
# | 0   | 1111010100 | 2023-04-30 | 서울특별시 | 종로구   | 청운동   | 청운동 | 2339  | 서울특별시 종로구 청운동 |
# | 1   | 1111010200 | 2023-04-30 | 서울특별시 | 종로구   | 신교동   | 신교동 | 1361  | 서울특별시 종로구 신교동 |
# | 2   | 1111010300 | 2023-04-30 | 서울특별시 | 종로구   | 궁정동   | 궁정동 | 192   | 서울특별시 종로구 궁정동 |
# | 3   | 1111010400 | 2023-04-30 | 서울특별시 | 종로구   | 효자동   | 효자동 | 572   | 서울특별시 종로구 효자동 |
# | 4   | 1111010500 | 2023-04-30 | 서울특별시 | 종로구   | 창성동   | 창성동 | 414   | 서울특별시 종로구 창성동 |
# | ... | ...        | ...        | ...        | ...      | ...      | ...    | ...   | ...                      |
# | 450 | 1174010600 | 2023-04-30 | 서울특별시 | 강동구   | 둔촌동   | 둔촌동 | 24160 | 서울특별시 강동구 둔촌동 |
# | 451 | 1174010700 | 2023-04-30 | 서울특별시 | 강동구   | 암사동   | 암사동 | 66418 | 서울특별시 강동구 암사동 |
# | 452 | 1174010800 | 2023-04-30 | 서울특별시 | 강동구   | 성내동   | 성내동 | 65051 | 서울특별시 강동구 성내동 |
# | 453 | 1174010900 | 2023-04-30 | 서울특별시 | 강동구   | 천호동   | 천호동 | 85764 | 서울특별시 강동구 천호동 |
# | 454 | 1174011000 | 2023-04-30 | 서울특별시 | 강동구   | 강일동   | 강일동 | 32855 | 서울특별시 강동구 강일동 |
#
# 455 rows × 8 columns
#
# In \[5\]:
#
#     법정동=법정동[['법정동','계']]
#     법정동.columns=['법정동','인구수']
#
# In \[6\]:
#
#     법정동
#
# Out\[6\]:
#
# |     | 법정동                   | 인구수 |
# |-----|--------------------------|--------|
# | 0   | 서울특별시 종로구 청운동 | 2339   |
# | 1   | 서울특별시 종로구 신교동 | 1361   |
# | 2   | 서울특별시 종로구 궁정동 | 192    |
# | 3   | 서울특별시 종로구 효자동 | 572    |
# | 4   | 서울특별시 종로구 창성동 | 414    |
# | ... | ...                      | ...    |
# | 450 | 서울특별시 강동구 둔촌동 | 24160  |
# | 451 | 서울특별시 강동구 암사동 | 66418  |
# | 452 | 서울특별시 강동구 성내동 | 65051  |
# | 453 | 서울특별시 강동구 천호동 | 85764  |
# | 454 | 서울특별시 강동구 강일동 | 32855  |
#
# 455 rows × 2 columns
#
# In \[7\]:
#
#     #법정동['법정동명'] = 법정동['법정동'].str.split().str[-1]
#     법정동=법정동[['법정동','인구수']]
#
# In \[8\]:
#
#     안심택배함=pd.read_csv("안심택배함법정동.csv",encoding="cp949")
#
# In \[9\]:
#
#     안심택배함_합계 = 안심택배함.groupby('법정동')['택배함 개수'].sum()
#
# In \[10\]:
#
#     서울특별시_아닌_행 = 안심택배함[~안심택배함['법정동'].str.contains('서울특별시')]
#     서울특별시_아닌_행
#
# Out\[10\]:
#
# |     | Unnamed: 0 | 행정동 | 택배함 개수 | 위도 | 경도 | 법정동 |
# |-----|------------|--------|-------------|------|------|--------|
#
# In \[11\]:
#
#     안심택배함3 = pd.DataFrame(list(안심택배함_합계.items()), columns=['법정동', '택배함 개수'])
#     안심택배함3
#
# Out\[11\]:
#
# |     | 법정동                    | 택배함 개수 |
# |-----|---------------------------|-------------|
# | 0   | 서울특별시 강남구 논현동  | 1           |
# | 1   | 서울특별시 강남구 대치동  | 2           |
# | 2   | 서울특별시 강남구 도곡동  | 2           |
# | 3   | 서울특별시 강남구 신사동  | 2           |
# | 4   | 서울특별시 강남구 역삼동  | 2           |
# | ... | ...                       | ...         |
# | 126 | 서울특별시 중구 신당동    | 4           |
# | 127 | 서울특별시 중구 장충동2가 | 2           |
# | 128 | 서울특별시 중랑구 면목동  | 3           |
# | 129 | 서울특별시 중랑구 상봉동  | 2           |
# | 130 | 서울특별시 중랑구 중화동  | 1           |
#
# 131 rows × 2 columns
#
# In \[12\]:
#
#     안심택배함3['택배함 개수'].sum()
#
# Out\[12\]:
#
#     264
#
# In \[13\]:
#
#     안심택배함5 = 안심택배함3.groupby('법정동')['택배함 개수'].sum().reset_index()
#     안심택배함5
#
# Out\[13\]:
#
# |     | 법정동                    | 택배함 개수 |
# |-----|---------------------------|-------------|
# | 0   | 서울특별시 강남구 논현동  | 1           |
# | 1   | 서울특별시 강남구 대치동  | 2           |
# | 2   | 서울특별시 강남구 도곡동  | 2           |
# | 3   | 서울특별시 강남구 신사동  | 2           |
# | 4   | 서울특별시 강남구 역삼동  | 2           |
# | ... | ...                       | ...         |
# | 126 | 서울특별시 중구 신당동    | 4           |
# | 127 | 서울특별시 중구 장충동2가 | 2           |
# | 128 | 서울특별시 중랑구 면목동  | 3           |
# | 129 | 서울특별시 중랑구 상봉동  | 2           |
# | 130 | 서울특별시 중랑구 중화동  | 1           |
#
# 131 rows × 2 columns
#
# In \[14\]:
#
#     #안심택배함5['법정동명'] = 안심택배함5['법정동'].str.split().str[-1]
#     안심택배함5
#
# Out\[14\]:
#
# |     | 법정동                    | 택배함 개수 |
# |-----|---------------------------|-------------|
# | 0   | 서울특별시 강남구 논현동  | 1           |
# | 1   | 서울특별시 강남구 대치동  | 2           |
# | 2   | 서울특별시 강남구 도곡동  | 2           |
# | 3   | 서울특별시 강남구 신사동  | 2           |
# | 4   | 서울특별시 강남구 역삼동  | 2           |
# | ... | ...                       | ...         |
# | 126 | 서울특별시 중구 신당동    | 4           |
# | 127 | 서울특별시 중구 장충동2가 | 2           |
# | 128 | 서울특별시 중랑구 면목동  | 3           |
# | 129 | 서울특별시 중랑구 상봉동  | 2           |
# | 130 | 서울특별시 중랑구 중화동  | 1           |
#
# 131 rows × 2 columns
#
# In \[15\]:
#
#     안심택배함5=안심택배함5[['법정동','택배함 개수']]
#
# In \[16\]:
#
#     안심택배함5['택배함 개수'].sum()
#
# Out\[16\]:
#
#     264
#
# In \[17\]:
#
#     물류창고=pd.read_csv("물류창고법정동.csv",encoding="cp949")
#
# In \[18\]:
#
#     # 서울시 물류창고 69개
#     물류창고
#
# Out\[18\]:
#
# |     | Unnamed: 0 | 개방서비스명 | 사업장명                            | 도로명전체주소                                                          | 행정동                                                      | 행정동2                             | 위도      | 경도       | 법정동                          |
# |-----|------------|--------------|-------------------------------------|-------------------------------------------------------------------------|-------------------------------------------------------------|-------------------------------------|-----------|------------|---------------------------------|
# | 0   | 0          | 물류창고업체 | 주식회사 참존                       | 서울특별시 강남구 영동대로 318 (대치동)                                 | 서울특별시 강남구 영동대로 318                              | 서울특별시 강남구 영동대로 318      | 37.502701 | 127.067192 | 서울특별시 강남구 대치동        |
# | 1   | 1          | 물류창고업체 | 롯데글로벌로지스(주) 서울구로지점   | 서울특별시 금천구 디지털로 154 (가산동)                                 | 서울특별시 금천구 디지털로 154                              | 서울특별시 금천구 디지털로 154      | 37.475783 | 126.880603 | 서울특별시 금천구 가산동        |
# | 2   | 2          | 물류창고업체 | 이화창고                            | 서울특별시 도봉구 도봉로180길 9 (도봉동)                                | 서울특별시 도봉구 도봉로180길 9                             | 서울특별시 도봉구 도봉로180길 9     | 37.682074 | 127.047437 | 서울특별시 도봉구 도봉동        |
# | 3   | 3          | 물류창고업체 | 롯데글로벌로지스(주) 영등포제과센터 | 서울특별시 영등포구 양평로21길 25 (양평동4가)                           | 서울특별시 영등포구 양평로21길 25                           | 서울특별시 영등포구 양평로21길 25   | 37.536727 | 126.893060 | 서울특별시 영등포구 양평동4가   |
# | 4   | 4          | 물류창고업체 | 주식회사 3피엘                      | 서울특별시 금천구 가산디지털2로 156 (가산동)                            | 서울특별시 금천구 가산디지털2로 156                         | 서울특별시 금천구 가산디지털2로 156 | 37.480258 | 126.878925 | 서울특별시 금천구 가산동        |
# | ... | ...        | ...          | ...                                 | ...                                                                     | ...                                                         | ...                                 | ...       | ...        | ...                             |
# | 64  | 64         | 물류창고업체 | 롯데로지스틱스(주) 독산알미늄센터   | 서울특별시 금천구 벚꽃로 88 (독산동)                                    | 서울특별시 금천구 벚꽃로 88                                 | 서울특별시 금천구 벚꽃로 88         | 37.473876 | 126.885452 | 서울특별시 금천구 가산동        |
# | 65  | 65         | 물류창고업체 | (주)판토스 (구로물류)               | 서울특별시 구로구 경인로 110 (오류동)                                   | 서울특별시 구로구 경인로 110                                | 서울특별시 구로구 경인로 110        | 37.496050 | 126.863064 | 서울특별시 구로구 개봉동        |
# | 66  | 66         | 물류창고업체 | 한국농수산식품유통공사              | 서울특별시 동작구 노들로 674 (노량진동)                                 | 서울특별시 동작구 노들로 674                                | 서울특별시 동작구 노들로 674        | 37.514716 | 126.937737 | 서울특별시 동작구 노량진동      |
# | 67  | 67         | 물류창고업체 | 한솔로지스틱스(주) 용산             | 서울특별시 용산구 이촌로 343-20, 용산동창고시설 1동 1층 1호 (용산동6가) | 서울특별시 용산구 이촌로 343-20, 용산동창고시설 1동 1층 1호 | 서울특별시 용산구 이촌로 343-20     | 37.521800 | 126.964763 | 서울특별시 용산구 이촌동        |
# | 68  | 68         | 물류창고업체 | 서영물류(주)                        | 서울특별시 영등포구 영등포로 154 (당산동1가)                            | 서울특별시 영등포구 영등포로 154                            | 서울특별시 영등포구 영등포로 154    | 37.518508 | 126.912833 | 서울특별시 영등포구 영등포동1가 |
#
# 69 rows × 9 columns
#
# In \[19\]:
#
#     물류창고_address_count = 물류창고['법정동'].value_counts()
#     물류창고2 = dict(물류창고_address_count)
#     물류창고3 = pd.DataFrame(list(물류창고2.items()), columns=['법정동', '물류창고 개수'])
#     물류창고3
#
# Out\[19\]:
#
# |     | 법정동                          | 물류창고 개수 |
# |-----|---------------------------------|---------------|
# | 0   | 서울특별시 금천구 가산동        | 12            |
# | 1   | 서울특별시 송파구 잠실동        | 9             |
# | 2   | 서울특별시 성동구 성수동2가     | 6             |
# | 3   | 서울특별시 강서구 공항동        | 5             |
# | 4   | 서울특별시 강서구 외발산동      | 4             |
# | 5   | 서울특별시 구로구 개봉동        | 4             |
# | 6   | 서울특별시 강서구 염창동        | 3             |
# | 7   | 서울특별시 마포구 상암동        | 2             |
# | 8   | 서울특별시 노원구 월계동        | 2             |
# | 9   | 서울특별시 서초구 양재동        | 2             |
# | 10  | 서울특별시 도봉구 도봉동        | 2             |
# | 11  | 서울특별시 서초구 서초동        | 1             |
# | 12  | 서울특별시 구로구 구로동        | 1             |
# | 13  | 서울특별시 영등포구 영등포동2가 | 1             |
# | 14  | 서울특별시 영등포구 당산동1가   | 1             |
# | 15  | 서울특별시 동작구 노량진동      | 1             |
# | 16  | 서울특별시 영등포구 양평동3가   | 1             |
# | 17  | 서울특별시 용산구 이촌동        | 1             |
# | 18  | 서울특별시 강남구 대치동        | 1             |
# | 19  | 서울특별시 강북구 미아동        | 1             |
# | 20  | 서울특별시 강서구 마곡동        | 1             |
# | 21  | 서울특별시 영등포구 양평동5가   | 1             |
# | 22  | 서울특별시 성동구 성수동1가     | 1             |
# | 23  | 서울특별시 영등포구 당산동4가   | 1             |
# | 24  | 서울특별시 용산구 서빙고동      | 1             |
# | 25  | 서울특별시 강남구 수서동        | 1             |
# | 26  | 서울특별시 강서구 과해동        | 1             |
# | 27  | 서울특별시 영등포구 양평동4가   | 1             |
# | 28  | 서울특별시 영등포구 영등포동1가 | 1             |
#
# In \[20\]:
#
#     물류창고3['물류창고 개수'].sum()
#
# Out\[20\]:
#
#     69
#
# In \[21\]:
#
#     물류창고4 = 물류창고3.groupby('법정동')['물류창고 개수'].sum().reset_index()
#     물류창고4
#
# Out\[21\]:
#
# |     | 법정동                          | 물류창고 개수 |
# |-----|---------------------------------|---------------|
# | 0   | 서울특별시 강남구 대치동        | 1             |
# | 1   | 서울특별시 강남구 수서동        | 1             |
# | 2   | 서울특별시 강북구 미아동        | 1             |
# | 3   | 서울특별시 강서구 공항동        | 5             |
# | 4   | 서울특별시 강서구 과해동        | 1             |
# | 5   | 서울특별시 강서구 마곡동        | 1             |
# | 6   | 서울특별시 강서구 염창동        | 3             |
# | 7   | 서울특별시 강서구 외발산동      | 4             |
# | 8   | 서울특별시 구로구 개봉동        | 4             |
# | 9   | 서울특별시 구로구 구로동        | 1             |
# | 10  | 서울특별시 금천구 가산동        | 12            |
# | 11  | 서울특별시 노원구 월계동        | 2             |
# | 12  | 서울특별시 도봉구 도봉동        | 2             |
# | 13  | 서울특별시 동작구 노량진동      | 1             |
# | 14  | 서울특별시 마포구 상암동        | 2             |
# | 15  | 서울특별시 서초구 서초동        | 1             |
# | 16  | 서울특별시 서초구 양재동        | 2             |
# | 17  | 서울특별시 성동구 성수동1가     | 1             |
# | 18  | 서울특별시 성동구 성수동2가     | 6             |
# | 19  | 서울특별시 송파구 잠실동        | 9             |
# | 20  | 서울특별시 영등포구 당산동1가   | 1             |
# | 21  | 서울특별시 영등포구 당산동4가   | 1             |
# | 22  | 서울특별시 영등포구 양평동3가   | 1             |
# | 23  | 서울특별시 영등포구 양평동4가   | 1             |
# | 24  | 서울특별시 영등포구 양평동5가   | 1             |
# | 25  | 서울특별시 영등포구 영등포동1가 | 1             |
# | 26  | 서울특별시 영등포구 영등포동2가 | 1             |
# | 27  | 서울특별시 용산구 서빙고동      | 1             |
# | 28  | 서울특별시 용산구 이촌동        | 1             |
#
# In \[22\]:
#
#     #물류창고4['법정동명'] = 물류창고4['법정동'].str.split().str[-1]
#
# In \[23\]:
#
#     물류창고4=물류창고4[['법정동','물류창고 개수']]
#
# In \[24\]:
#
#     물류창고4['물류창고 개수'].sum()
#
# Out\[24\]:
#
#     69
#
# In \[25\]:
#
#     전기차_등록=pd.read_csv("전기차등록수법정동.csv",encoding="cp949")
#     전기차_등록=전기차_등록[["전기차 등록 수", "법정동"]]
#     전기차_등록
#
# Out\[25\]:
#
# |     | 전기차 등록 수 | 법정동                       |
# |-----|----------------|------------------------------|
# | 0   | 5339           | 서울특별시 강남구 대치동     |
# | 1   | 3216           | 서울특별시 강남구 대치동     |
# | 2   | 1579           | 서울특별시 강남구 대치동     |
# | 3   | 1577           | 서울특별시 구로구 구로동     |
# | 4   | 1537           | 서울특별시 영등포구 여의도동 |
# | ... | ...            | ...                          |
# | 423 | 8              | 서울특별시 구로구 가리봉동   |
# | 424 | 7              | 서울특별시 종로구 창신동     |
# | 425 | 6              | 서울특별시 강동구 둔촌동     |
# | 426 | 4              | 서울특별시 종로구 창신동     |
# | 427 | 1              | 서울특별시 강북구 수유동     |
#
# 428 rows × 2 columns
#
# In \[26\]:
#
#     전기차_등록['전기차 등록 수'].sum()
#
# Out\[26\]:
#
#     45133
#
# In \[27\]:
#
#     서울특별시_아닌_행 = 전기차_등록[~전기차_등록['법정동'].str.contains('서울특별시')]
#     서울특별시_아닌_행
#
# Out\[27\]:
#
# |     | 전기차 등록 수 | 법정동 |
# |-----|----------------|--------|
#
# In \[28\]:
#
#     전기차_등록2 = 전기차_등록.groupby('법정동')['전기차 등록 수'].sum().reset_index()
#     전기차_등록2
#
# Out\[28\]:
#
# |     | 법정동                   | 전기차 등록 수 |
# |-----|--------------------------|----------------|
# | 0   | 서울특별시 강남구 개포동 | 366            |
# | 1   | 서울특별시 강남구 논현동 | 193            |
# | 2   | 서울특별시 강남구 대치동 | 10134          |
# | 3   | 서울특별시 강남구 도곡동 | 275            |
# | 4   | 서울특별시 강남구 삼성동 | 283            |
# | ... | ...                      | ...            |
# | 211 | 서울특별시 중랑구 면목동 | 262            |
# | 212 | 서울특별시 중랑구 묵동   | 94             |
# | 213 | 서울특별시 중랑구 상봉동 | 100            |
# | 214 | 서울특별시 중랑구 신내동 | 205            |
# | 215 | 서울특별시 중랑구 중화동 | 81             |
#
# 216 rows × 2 columns
#
# In \[29\]:
#
#     전기차_등록3 = 전기차_등록2.groupby('법정동')['전기차 등록 수'].sum().reset_index()
#     전기차_등록3
#
# Out\[29\]:
#
# |     | 법정동                   | 전기차 등록 수 |
# |-----|--------------------------|----------------|
# | 0   | 서울특별시 강남구 개포동 | 366            |
# | 1   | 서울특별시 강남구 논현동 | 193            |
# | 2   | 서울특별시 강남구 대치동 | 10134          |
# | 3   | 서울특별시 강남구 도곡동 | 275            |
# | 4   | 서울특별시 강남구 삼성동 | 283            |
# | ... | ...                      | ...            |
# | 211 | 서울특별시 중랑구 면목동 | 262            |
# | 212 | 서울특별시 중랑구 묵동   | 94             |
# | 213 | 서울특별시 중랑구 상봉동 | 100            |
# | 214 | 서울특별시 중랑구 신내동 | 205            |
# | 215 | 서울특별시 중랑구 중화동 | 81             |
#
# 216 rows × 2 columns
#
# In \[30\]:
#
#     #전기차_등록3['법정동명'] = 전기차_등록3['법정동'].str.split().str[-1]
#
# In \[31\]:
#
#     전기차_등록3=전기차_등록3[['법정동','전기차 등록 수']]
#
# In \[32\]:
#
#     전기차_등록3['전기차 등록 수'].sum()
#
# Out\[32\]:
#
#     45133
#
# In \[33\]:
#
#     충전기=pd.read_csv("전기차충전기법정동수정필요.csv",encoding="cp949")
#
# In \[34\]:
#
#     충전기['충전기 개수'].sum()
#
# Out\[34\]:
#
#     1538
#
# In \[35\]:
#
#     충전기['주소2'] = 충전기['주소2'].str.strip()
#
# In \[36\]:
#
#     서울특별시_아닌_행 = 충전기[~충전기['주소2'].str.contains('서울특별시')]
#     서울특별시_아닌_행
#
# Out\[36\]:
#
# |     | Unnamed: 0 | 주소2 | 충전기 개수 |
# |-----|------------|-------|-------------|
#
# In \[37\]:
#
#     충전기_합계 = 충전기.groupby('주소2')['충전기 개수'].sum()
#
# In \[38\]:
#
#     충전기_합계.sum()
#
# Out\[38\]:
#
#     1538
#
# In \[39\]:
#
#     충전기3 = pd.DataFrame(list(충전기_합계.items()), columns=['법정동', '충전기 개수'])
#     충전기3
#
# Out\[39\]:
#
# |     | 법정동                   | 충전기 개수 |
# |-----|--------------------------|-------------|
# | 0   | 서울특별시 강남구 개포동 | 4           |
# | 1   | 서울특별시 강남구 논현동 | 4           |
# | 2   | 서울특별시 강남구 대치동 | 10          |
# | 3   | 서울특별시 강남구 도곡동 | 17          |
# | 4   | 서울특별시 강남구 삼성동 | 18          |
# | ... | ...                      | ...         |
# | 195 | 서울특별시 중랑구 면목동 | 8           |
# | 196 | 서울특별시 중랑구 묵동   | 7           |
# | 197 | 서울특별시 중랑구 상봉동 | 8           |
# | 198 | 서울특별시 중랑구 신내동 | 6           |
# | 199 | 서울특별시 중랑구 중화동 | 9           |
#
# 200 rows × 2 columns
#
# In \[40\]:
#
#     충전기4 = 충전기3.groupby('법정동')['충전기 개수'].sum().reset_index()
#     충전기4
#
# Out\[40\]:
#
# |     | 법정동                   | 충전기 개수 |
# |-----|--------------------------|-------------|
# | 0   | 서울특별시 강남구 개포동 | 4           |
# | 1   | 서울특별시 강남구 논현동 | 4           |
# | 2   | 서울특별시 강남구 대치동 | 10          |
# | 3   | 서울특별시 강남구 도곡동 | 17          |
# | 4   | 서울특별시 강남구 삼성동 | 18          |
# | ... | ...                      | ...         |
# | 195 | 서울특별시 중랑구 면목동 | 8           |
# | 196 | 서울특별시 중랑구 묵동   | 7           |
# | 197 | 서울특별시 중랑구 상봉동 | 8           |
# | 198 | 서울특별시 중랑구 신내동 | 6           |
# | 199 | 서울특별시 중랑구 중화동 | 9           |
#
# 200 rows × 2 columns
#
# In \[41\]:
#
#     #충전기4['법정동명'] = 충전기4['법정동'].str.split().str[-1]
#
# In \[42\]:
#
#     충전기4=충전기4[['법정동','충전기 개수']]
#
# In \[43\]:
#
#     충전기4['충전기 개수'].sum()
#
# Out\[43\]:
#
#     1538
#
# In \[44\]:
#
#     join_1 = pd.merge(법정동, 안심택배함5, on='법정동', how='left')
#     join_1
#
# Out\[44\]:
#
# |     | 법정동                   | 인구수 | 택배함 개수 |
# |-----|--------------------------|--------|-------------|
# | 0   | 서울특별시 종로구 청운동 | 2339   | NaN         |
# | 1   | 서울특별시 종로구 신교동 | 1361   | NaN         |
# | 2   | 서울특별시 종로구 궁정동 | 192    | 1.0         |
# | 3   | 서울특별시 종로구 효자동 | 572    | NaN         |
# | 4   | 서울특별시 종로구 창성동 | 414    | NaN         |
# | ... | ...                      | ...    | ...         |
# | 450 | 서울특별시 강동구 둔촌동 | 24160  | NaN         |
# | 451 | 서울특별시 강동구 암사동 | 66418  | 2.0         |
# | 452 | 서울특별시 강동구 성내동 | 65051  | 3.0         |
# | 453 | 서울특별시 강동구 천호동 | 85764  | 4.0         |
# | 454 | 서울특별시 강동구 강일동 | 32855  | NaN         |
#
# 455 rows × 3 columns
#
# In \[45\]:
#
#     join_1 = join_1.drop_duplicates()
#
# In \[46\]:
#
#     join_2 = pd.merge(join_1, 물류창고4, on='법정동', how='left')
#
# In \[47\]:
#
#     join_2 ['택배함 개수'] = join_2 ['택배함 개수'].fillna(0).astype(int)
#     join_2 ['물류창고 개수'] = join_2 ['물류창고 개수'].fillna(0).astype(int)
#
# In \[48\]:
#
#     join_3 = pd.merge(join_2, 전기차_등록3, on='법정동', how='left')
#
# In \[49\]:
#
#     join_3['전기차 등록 수'] = join_3['전기차 등록 수'].fillna(0).astype(int)
#
# In \[50\]:
#
#     join_3
#
# Out\[50\]:
#
# |     | 법정동                   | 인구수 | 택배함 개수 | 물류창고 개수 | 전기차 등록 수 |
# |-----|--------------------------|--------|-------------|---------------|----------------|
# | 0   | 서울특별시 종로구 청운동 | 2339   | 0           | 0             | 0              |
# | 1   | 서울특별시 종로구 신교동 | 1361   | 0           | 0             | 0              |
# | 2   | 서울특별시 종로구 궁정동 | 192    | 1           | 0             | 55             |
# | 3   | 서울특별시 종로구 효자동 | 572    | 0           | 0             | 0              |
# | 4   | 서울특별시 종로구 창성동 | 414    | 0           | 0             | 0              |
# | ... | ...                      | ...    | ...         | ...           | ...            |
# | 450 | 서울특별시 강동구 둔촌동 | 24160  | 0           | 0             | 151            |
# | 451 | 서울특별시 강동구 암사동 | 66418  | 2           | 0             | 155            |
# | 452 | 서울특별시 강동구 성내동 | 65051  | 3           | 0             | 202            |
# | 453 | 서울특별시 강동구 천호동 | 85764  | 4           | 0             | 210            |
# | 454 | 서울특별시 강동구 강일동 | 32855  | 0           | 0             | 161            |
#
# 455 rows × 5 columns
#
# In \[51\]:
#
#     join_4 = pd.merge(join_3, 충전기4, on='법정동', how='left')
#     join_4
#
# Out\[51\]:
#
# |     | 법정동                   | 인구수 | 택배함 개수 | 물류창고 개수 | 전기차 등록 수 | 충전기 개수 |
# |-----|--------------------------|--------|-------------|---------------|----------------|-------------|
# | 0   | 서울특별시 종로구 청운동 | 2339   | 0           | 0             | 0              | NaN         |
# | 1   | 서울특별시 종로구 신교동 | 1361   | 0           | 0             | 0              | NaN         |
# | 2   | 서울특별시 종로구 궁정동 | 192    | 1           | 0             | 55             | NaN         |
# | 3   | 서울특별시 종로구 효자동 | 572    | 0           | 0             | 0              | NaN         |
# | 4   | 서울특별시 종로구 창성동 | 414    | 0           | 0             | 0              | NaN         |
# | ... | ...                      | ...    | ...         | ...           | ...            | ...         |
# | 450 | 서울특별시 강동구 둔촌동 | 24160  | 0           | 0             | 151            | 12.0        |
# | 451 | 서울특별시 강동구 암사동 | 66418  | 2           | 0             | 155            | 10.0        |
# | 452 | 서울특별시 강동구 성내동 | 65051  | 3           | 0             | 202            | 14.0        |
# | 453 | 서울특별시 강동구 천호동 | 85764  | 4           | 0             | 210            | 7.0         |
# | 454 | 서울특별시 강동구 강일동 | 32855  | 0           | 0             | 161            | 14.0        |
#
# 455 rows × 6 columns
#
# In \[52\]:
#
#     join_4['충전기 개수'] = join_4['충전기 개수'].fillna(0).astype(int)
#
# In \[53\]:
#
#     join_4['전기차한대당충전소개수']=join_4['충전기 개수']/join_4['전기차 등록 수']
#     join_4
#
# Out\[53\]:
#
# |     | 법정동                   | 인구수 | 택배함 개수 | 물류창고 개수 | 전기차 등록 수 | 충전기 개수 | 전기차한대당충전소개수 |
# |-----|--------------------------|--------|-------------|---------------|----------------|-------------|------------------------|
# | 0   | 서울특별시 종로구 청운동 | 2339   | 0           | 0             | 0              | 0           | NaN                    |
# | 1   | 서울특별시 종로구 신교동 | 1361   | 0           | 0             | 0              | 0           | NaN                    |
# | 2   | 서울특별시 종로구 궁정동 | 192    | 1           | 0             | 55             | 0           | 0.000000               |
# | 3   | 서울특별시 종로구 효자동 | 572    | 0           | 0             | 0              | 0           | NaN                    |
# | 4   | 서울특별시 종로구 창성동 | 414    | 0           | 0             | 0              | 0           | NaN                    |
# | ... | ...                      | ...    | ...         | ...           | ...            | ...         | ...                    |
# | 450 | 서울특별시 강동구 둔촌동 | 24160  | 0           | 0             | 151            | 12          | 0.079470               |
# | 451 | 서울특별시 강동구 암사동 | 66418  | 2           | 0             | 155            | 10          | 0.064516               |
# | 452 | 서울특별시 강동구 성내동 | 65051  | 3           | 0             | 202            | 14          | 0.069307               |
# | 453 | 서울특별시 강동구 천호동 | 85764  | 4           | 0             | 210            | 7           | 0.033333               |
# | 454 | 서울특별시 강동구 강일동 | 32855  | 0           | 0             | 161            | 14          | 0.086957               |
#
# 455 rows × 7 columns
#
# In \[54\]:
#
#     join_4['전기차한대당충전소개수'] = join_4['전기차한대당충전소개수'].replace([np.inf, -np.inf], 0)
#
# In \[55\]:
#
#     join_4
#
# Out\[55\]:
#
# |     | 법정동                   | 인구수 | 택배함 개수 | 물류창고 개수 | 전기차 등록 수 | 충전기 개수 | 전기차한대당충전소개수 |
# |-----|--------------------------|--------|-------------|---------------|----------------|-------------|------------------------|
# | 0   | 서울특별시 종로구 청운동 | 2339   | 0           | 0             | 0              | 0           | NaN                    |
# | 1   | 서울특별시 종로구 신교동 | 1361   | 0           | 0             | 0              | 0           | NaN                    |
# | 2   | 서울특별시 종로구 궁정동 | 192    | 1           | 0             | 55             | 0           | 0.000000               |
# | 3   | 서울특별시 종로구 효자동 | 572    | 0           | 0             | 0              | 0           | NaN                    |
# | 4   | 서울특별시 종로구 창성동 | 414    | 0           | 0             | 0              | 0           | NaN                    |
# | ... | ...                      | ...    | ...         | ...           | ...            | ...         | ...                    |
# | 450 | 서울특별시 강동구 둔촌동 | 24160  | 0           | 0             | 151            | 12          | 0.079470               |
# | 451 | 서울특별시 강동구 암사동 | 66418  | 2           | 0             | 155            | 10          | 0.064516               |
# | 452 | 서울특별시 강동구 성내동 | 65051  | 3           | 0             | 202            | 14          | 0.069307               |
# | 453 | 서울특별시 강동구 천호동 | 85764  | 4           | 0             | 210            | 7           | 0.033333               |
# | 454 | 서울특별시 강동구 강일동 | 32855  | 0           | 0             | 161            | 14          | 0.086957               |
#
# 455 rows × 7 columns
#
# In \[56\]:
#
#     join_4 = join_4.fillna(0)
#
# In \[57\]:
#
#     pd.set_option('display.max_rows', None)
#
# In \[58\]:
#
#     join_4
#
# Out\[58\]:
#
# |     | 법정동                          | 인구수 | 택배함 개수 | 물류창고 개수 | 전기차 등록 수 | 충전기 개수 | 전기차한대당충전소개수 |
# |-----|---------------------------------|--------|-------------|---------------|----------------|-------------|------------------------|
# | 0   | 서울특별시 종로구 청운동        | 2339   | 0           | 0             | 0              | 0           | 0.000000               |
# | 1   | 서울특별시 종로구 신교동        | 1361   | 0           | 0             | 0              | 0           | 0.000000               |
# | 2   | 서울특별시 종로구 궁정동        | 192    | 1           | 0             | 55             | 0           | 0.000000               |
# | 3   | 서울특별시 종로구 효자동        | 572    | 0           | 0             | 0              | 0           | 0.000000               |
# | 4   | 서울특별시 종로구 창성동        | 414    | 0           | 0             | 0              | 0           | 0.000000               |
# | 5   | 서울특별시 종로구 통의동        | 318    | 0           | 0             | 0              | 0           | 0.000000               |
# | 6   | 서울특별시 종로구 적선동        | 33     | 0           | 0             | 0              | 0           | 0.000000               |
# | 7   | 서울특별시 종로구 통인동        | 756    | 0           | 0             | 0              | 0           | 0.000000               |
# | 8   | 서울특별시 종로구 누상동        | 3206   | 0           | 0             | 0              | 0           | 0.000000               |
# | 9   | 서울특별시 종로구 누하동        | 811    | 0           | 0             | 0              | 0           | 0.000000               |
# | 10  | 서울특별시 종로구 옥인동        | 1880   | 0           | 0             | 0              | 0           | 0.000000               |
# | 11  | 서울특별시 종로구 체부동        | 715    | 0           | 0             | 0              | 0           | 0.000000               |
# | 12  | 서울특별시 종로구 필운동        | 994    | 0           | 0             | 0              | 0           | 0.000000               |
# | 13  | 서울특별시 종로구 내자동        | 89     | 0           | 0             | 0              | 0           | 0.000000               |
# | 14  | 서울특별시 종로구 사직동        | 3193   | 0           | 0             | 0              | 4           | 0.000000               |
# | 15  | 서울특별시 종로구 도렴동        | 1      | 0           | 0             | 0              | 0           | 0.000000               |
# | 16  | 서울특별시 종로구 당주동        | 301    | 0           | 0             | 0              | 0           | 0.000000               |
# | 17  | 서울특별시 종로구 내수동        | 2655   | 0           | 0             | 146            | 2           | 0.013699               |
# | 18  | 서울특별시 종로구 신문로1가     | 77     | 0           | 0             | 0              | 0           | 0.000000               |
# | 441 | 서울특별시 송파구 장지동        | 43536  | 1           | 0             | 294            | 43          | 0.146259               |
# | 442 | 서울특별시 송파구 방이동        | 58954  | 1           | 0             | 181            | 3           | 0.016575               |
# | 443 | 서울특별시 송파구 오금동        | 37664  | 0           | 0             | 107            | 2           | 0.018692               |
# | 444 | 서울특별시 송파구 거여동        | 52557  | 2           | 0             | 91             | 16          | 0.175824               |
# | 445 | 서울특별시 송파구 마천동        | 36246  | 1           | 0             | 98             | 7           | 0.071429               |
# | 446 | 서울특별시 강동구 명일동        | 42683  | 1           | 0             | 110            | 5           | 0.045455               |
# | 447 | 서울특별시 강동구 고덕동        | 46595  | 0           | 0             | 210            | 4           | 0.019048               |
# | 448 | 서울특별시 강동구 상일동        | 51232  | 0           | 0             | 105            | 10          | 0.095238               |
# | 449 | 서울특별시 강동구 길동          | 44809  | 1           | 0             | 207            | 9           | 0.043478               |
# | 450 | 서울특별시 강동구 둔촌동        | 24160  | 0           | 0             | 151            | 12          | 0.079470               |
# | 451 | 서울특별시 강동구 암사동        | 66418  | 2           | 0             | 155            | 10          | 0.064516               |
# | 452 | 서울특별시 강동구 성내동        | 65051  | 3           | 0             | 202            | 14          | 0.069307               |
# | 453 | 서울특별시 강동구 천호동        | 85764  | 4           | 0             | 210            | 7           | 0.033333               |
# | 454 | 서울특별시 강동구 강일동        | 32855  | 0           | 0             | 161            | 14          | 0.086957               |
#
# In \[59\]:
#
#     join_4.describe()
#
# Out\[59\]:
#
# |       | 인구수        | 택배함 개수 | 물류창고 개수 | 전기차 등록 수 | 충전기 개수 | 전기차한대당충전소개수 |
# |-------|---------------|-------------|---------------|----------------|-------------|------------------------|
# | count | 455.000000    | 455.000000  | 455.000000    | 455.000000     | 455.000000  | 455.000000             |
# | mean  | 20709.287912  | 0.580220    | 0.149451      | 99.193407      | 3.272527    | 0.022376               |
# | std   | 34250.428984  | 1.258296    | 0.877819      | 516.972189     | 6.060671    | 0.053499               |
# | min   | 1.000000      | 0.000000    | 0.000000      | 0.000000       | 0.000000    | 0.000000               |
# | 25%   | 844.000000    | 0.000000    | 0.000000      | 0.000000       | 0.000000    | 0.000000               |
# | 50%   | 4615.000000   | 0.000000    | 0.000000      | 0.000000       | 0.000000    | 0.000000               |
# | 75%   | 30061.500000  | 1.000000    | 0.000000      | 99.000000      | 4.000000    | 0.024795               |
# | max   | 245562.000000 | 10.000000   | 12.000000     | 10134.000000   | 43.000000   | 0.625000               |
#
# In \[60\]:
#
#     join_4['택배함 개수'].sum()
#
# Out\[60\]:
#
#     264
#
# In \[61\]:
#
#     # 물류창고 데이터에 강서구 과해동이 있는데 법정동 데이터프레임에는 없음
#     join_4['물류창고 개수'].sum()
#
# Out\[61\]:
#
#     68
#
# In \[62\]:
#
#     join_4['전기차 등록 수'].sum()
#
# Out\[62\]:
#
#     45133
#
# In \[63\]:
#
#     # 강서구 과해동과 동일한 문제, 과해동, 봉래동2가...
#     join_4['충전기 개수'].sum()
#
# Out\[63\]:
#
#     1489
#
# In \[68\]:
#
#     #join_4.to_csv("data3.csv",encoding="cp949")
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[96\]:
#
#     from sklearn.cluster import KMeans
#     from sklearn.preprocessing import StandardScaler
#     import matplotlib.pyplot as plt
#     from sklearn import preprocessing
#
# In \[66\]:
#
#     법정동=pd.read_csv("data2.csv",encoding="cp949")
#
# In \[93\]:
#
#     df=법정동[['인구수','물류창고 개수','충전기 개수','택배함 개수']]
#
# In \[97\]:
#
#     df2=법정동[['인구수','물류창고 개수']]
#
# In \[94\]:
#
#     scaler = StandardScaler()
#     scaled_data = scaler.fit_transform(df)
#
# In \[98\]:
#
#     scaler = StandardScaler()
#     scaled_data2 = scaler.fit_transform(df2)
#
# In \[95\]:
#
#     from yellowbrick.cluster import KElbowVisualizer
#     model = KMeans()
#     visualizer = KElbowVisualizer(model, k=(1,20))
#     visualizer.fit(scaled_data)
#
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#
# Out\[95\]:
#
#     KElbowVisualizer(ax=<Axes: >, estimator=KMeans(n_clusters=19), k=(1, 20))
#
# **In a Jupyter environment, please rerun this cell to show the HTML
# representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try
# loading this page with nbviewer.org.**
#
# KElbowVisualizer
#
#     KElbowVisualizer(ax=<Axes: >, estimator=KMeans(n_clusters=19), k=(1, 20))
#
# estimator: KMeans
#
#     KMeans(n_clusters=19)
#
# KMeans
#
#     KMeans(n_clusters=19)
#
# ![](data:image/png;base64,...%0A)
#
# In \[99\]:
#
#     from yellowbrick.cluster import KElbowVisualizer
#     model = KMeans()
#     visualizer = KElbowVisualizer(model, k=(1,20))
#     visualizer.fit(scaled_data2)
#
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#
# Out\[99\]:
#
#     KElbowVisualizer(ax=<Axes: >, estimator=KMeans(n_clusters=19), k=(1, 20))
#
# **In a Jupyter environment, please rerun this cell to show the HTML
# representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try
# loading this page with nbviewer.org.**
#
# KElbowVisualizer
#
#     KElbowVisualizer(ax=<Axes: >, estimator=KMeans(n_clusters=19), k=(1, 20))
#
# estimator: KMeans
#
#     KMeans(n_clusters=19)
#
# KMeans
#
#     KMeans(n_clusters=19)
#
# ![](data:image/png;base64,...%0A)
#
# In \[ \]:
#
#     from sklearn import preprocessing
#
# In \[148\]:
#
#     processed_data = df2.copy()
#
# In \[149\]:
#
#     scaler = preprocessing.StandardScaler()
#     processed_data[['인구수', '물류창고 개수']] = scaler.fit_transform(processed_data[['인구수', '물류창고 개수']])
#
# In \[150\]:
#
#     plt.figure(figsize = (10, 10))
#
# Out\[150\]:
#
#     <Figure size 1000x1000 with 0 Axes>
#
#     <Figure size 1000x1000 with 0 Axes>
#
# In \[151\]:
#
#     plt.rcParams['font.family'] = 'Malgun Gothic'
#
# In \[152\]:
#
#     for i in range(1, 7):
#         estimator = KMeans(n_clusters = i)
#         ids = estimator.fit_predict(processed_data[['인구수', '물류창고 개수']])
#         plt.subplot(3, 2, i)
#         plt.tight_layout()
#         plt.title("K value = {}".format(i))
#         plt.xlabel('인구수')
#         plt.ylabel('물류창고 개수')
#         plt.scatter(processed_data['인구수'], processed_data['물류창고 개수'], c=ids, cmap='viridis')
#     plt.show()
#
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#       warnings.warn(
#     C:\Users\jaehy\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#       warnings.warn(
#
# ![](data:image/png;base64,...%0A)
